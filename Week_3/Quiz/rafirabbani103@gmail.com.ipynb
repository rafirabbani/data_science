# %% [markdown]
# # QUIZ-3
# Dataset-dataset berikut ini menunjukkan persentase lemak, protein, dan food yang dikonsumsi dari setiap jenis makanan yang terdaftar. Akhir dataset juga mencakup persentase obesitas dan kurang gizi, dan persentase kasus COVID-19 Terkonfirmasi/Kematian/Sembuh/Aktif (Catatan: Semua data memiliki unit% kecuali Populasi, Unit % tersebut berdasarkan jumlah populasi).
#
# Link Download:
#
# [Food_Supply_Quantity_kg_Data.csv](https://drive.google.com/uc?export=download&id=1EHSvX9TWPTQXwWLxW9xyKyM8EFoPohOW)
#
# [Protein_Supply_Quantity_Data.csv](https://drive.google.com/uc?export=download&id=1Qr4U9lQAVAI3Jcqk0n2HvVHulW_iaKAc)
#
# [Fat_Supply_Quantity_Data.csv](https://drive.google.com/uc?export=download&id=1VCzZyckdANfyqh2fJEUecXAt-uCJGxaT)
#
# [Supply_Food_Data_Descriptions.csv](https://drive.google.com/uc?export=download&id=1VwZsUhqtPTiQgGHQqjjMFXDriIu1_Gaz)

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 


# Import Semua Data
df_food = pd.read_csv('Food_Supply_Quantity_kg_Data.csv')
df_protein = pd.read_csv('Protein_Supply_Quantity_Data.csv')
df_fat = pd.read_csv('Fat_Supply_Quantity_Data.csv')
df_category = pd.read_csv('Supply_Food_Data_Descriptions.csv')

# %% [markdown]
# <h2> 1. Python Quiz: Memisahkan antara column tentang makanan yang di supply dan bukan makanan</h2>
#
# di akhir kita mempunyai data list berisi semua column tentang supply makanan dan non supply makanan atau column tentang covid-19 beserta populasi, cara kalian mendapatkannya bebas yang penting sesuai output.

# %% [markdown]
# Hasil Akhir Yang di harapkan :
#
# - supply columns => columns berisi column tentang semua jenis supply makanan
# - all columns => Semua columns
# - non supply columns => column column tentang data covid-19 + obesitas + Undernourished + populasi
#
# ![alt text](https://drive.google.com/uc?id=1OfUO60EJbM2ESz1BmNTQ_WGbGQ75h4eI)

# %%
# Code Here
non_supply_labels = ['Country', 'Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population', 'Unit (all except Population)']

supply_food = df_food[df_category['Categories']]
non_supply_food = df_food[non_supply_labels]
supply_fat = df_fat[df_category['Categories']]
supply_protein = df_protein[df_category['Categories']]

supply_columns = list(supply_food.columns)
all_columns = list(df_food.columns)
non_supply_columns = list(non_supply_food.columns)

print(supply_columns, '\n' + '\n', all_columns,'\n' + '\n', non_supply_columns)
# Out:
# ['Alcoholic Beverages', 'Animal fats', 'Animal Products', 'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs', 'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter', 'Miscellaneous', 'Offals', 'Oilcrops', 'Pulses', 'Spices', 'Starchy Roots', 'Stimulants', 'Sugar & Sweeteners', 'Sugar Crops', 'Treenuts', 'Vegetable Oils', 'Vegetables', 'Vegetal Products']
#
#  ['Country', 'Alcoholic Beverages', 'Animal fats', 'Animal Products', 'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs', 'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter', 'Miscellaneous', 'Offals', 'Oilcrops', 'Pulses', 'Spices', 'Starchy Roots', 'Stimulants', 'Sugar & Sweeteners', 'Sugar Crops', 'Treenuts', 'Vegetable Oils', 'Vegetables', 'Vegetal Products', 'Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population', 'Unit (all except Population)']
#
#  ['Country', 'Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population', 'Unit (all except Population)']

# %% [markdown]
# <h2>2. Pandas Quiz: Menggabungkan DataFrame </h2>
#
# Gabungkan Semua data dimana semua data nya berisi semua row dan column yang unik. berikan unique suffixes kepada nama column yang berlabel sama tapi berisi informasi yang berbeda.
#
# Tidak boleh ada column yang berisi data informasi yang sama.

# %% [markdown]
# Hasil akhir yang di harapkan mengenai data adalah seperti berikut:
#
# Lima data pertama :
#
# ![alt text](https://drive.google.com/uc?id=1pUqpDnU8V4zy58GEOF9bIWjbcXnhIICU)
#
# Dimensi data Hasil Gabung :
# (170, 78)
#
# Column Data Hasil Gabung, Perhatikan bahwa di setiap akhir nama column, nama column tersebut di tambahkan dengan suffixes berdasarkan asal data tersebut :
#
# ['Country', 'Alcoholic Beverages_food', 'Animal fats_food',
#        'Animal Products_food', 'Aquatic Products, Other_food',
#        'Cereals - Excluding Beer_food', 'Eggs_food', 'Fish, Seafood_food',
#        'Fruits - Excluding Wine_food', 'Meat_food',
#        'Milk - Excluding Butter_food', 'Miscellaneous_food', 'Offals_food',
#        'Oilcrops_food', 'Pulses_food', 'Spices_food', 'Starchy Roots_food',
#        'Stimulants_food', 'Sugar & Sweeteners_food', 'Sugar Crops_food',
#        'Treenuts_food', 'Vegetable Oils_food', 'Vegetables_food',
#        'Vegetal Products_food', 'Obesity', 'Undernourished', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'Population',
#        'Unit (all except Population)', 'Alcoholic Beverages_fat',
#        'Animal Products_fat', 'Animal fats_fat', 'Aquatic Products, Other_fat',
#        'Cereals - Excluding Beer_fat', 'Eggs_fat', 'Fish, Seafood_fat',
#        'Fruits - Excluding Wine_fat', 'Meat_fat', 'Miscellaneous_fat',
#        'Milk - Excluding Butter_fat', 'Offals_fat', 'Oilcrops_fat',
#        'Pulses_fat', 'Spices_fat', 'Starchy Roots_fat', 'Stimulants_fat',
#        'Sugar Crops_fat', 'Sugar & Sweeteners_fat', 'Treenuts_fat',
#        'Vegetal Products_fat', 'Vegetable Oils_fat', 'Vegetables_fat',
#        'Alcoholic Beverages_protein', 'Animal Products_protein',
#        'Animal fats_protein', 'Aquatic Products, Other_protein',
#        'Cereals - Excluding Beer_protein', 'Eggs_protein',
#        'Fish, Seafood_protein', 'Fruits - Excluding Wine_protein',
#        'Meat_protein', 'Milk - Excluding Butter_protein', 'Offals_protein',
#        'Oilcrops_protein', 'Pulses_protein', 'Spices_protein',
#        'Starchy Roots_protein', 'Stimulants_protein', 'Sugar Crops_protein',
#        'Sugar & Sweeteners_protein', 'Treenuts_protein',
#        'Vegetal Products_protein', 'Vegetable Oils_protein',
#        'Vegetables_protein', 'Miscellaneous_protein']

# %%
# Code Here
rename_list = []
rename_dict = {}
i = 0 
while i < len(supply_columns) :
    rename_list.append(supply_columns[i] + '_protein')
    rename_dict[supply_columns[i]] = rename_list[i]
    i += 1    


df_merge = df_food.merge(df_fat, how= 'left', on= non_supply_columns, suffixes= ('_food', '_fat')).merge(df_protein, how= 'left', on= non_supply_columns).rename(columns = rename_dict)

df_merge.head()
# Out:
#                Country  Alcoholic Beverages_food  Animal fats_food  \
# 0          Afghanistan                    0.0014            0.1973
# 1              Albania                    1.6719            0.1357
# 2              Algeria                    0.2711            0.0282
# 3               Angola                    5.8087            0.0560
# 4  Antigua and Barbuda                    3.5764            0.0087
#
#    Animal Products_food  Aquatic Products, Other_food  \
# 0                9.4341                           0.0
# 1               18.7684                           0.0
# 2                9.6334                           0.0
# 3                4.9278                           0.0
# 4               16.6613                           0.0
#
#    Cereals - Excluding Beer_food  Eggs_food  Fish, Seafood_food  \
# 0                        24.8097     0.2099              0.0350
# 1                         5.7817     0.5815              0.2126
# 2                        13.6816     0.5277              0.2416
# 3                         9.1085     0.0587              1.7707
# 4                         5.9960     0.2274              4.1489
#
#    Fruits - Excluding Wine_food  Meat_food  ...  Spices_protein  \
# 0                        5.3495     1.2020  ...          0.1664
# 1                        6.7861     1.8845  ...          0.0000
# 2                        6.3801     1.1305  ...          0.1776
# 3                        6.0005     2.0571  ...          0.0000
# 4                       10.7451     5.6888  ...          0.3438
#
#    Starchy Roots_protein  Stimulants_protein  Sugar Crops_protein  \
# 0                 0.1941              0.5546                  0.0
# 1                 0.8867              0.2635                  0.0
# 2                 1.4638              0.4628                  0.0
# 3                 5.1941              0.1017                  0.0
# 4                 0.4666              0.4113                  0.0
#
#    Sugar & Sweeteners_protein  Treenuts_protein  Vegetal Products_protein  \
# 0                      0.0000            0.1387                   40.2477
# 1                      0.0042            0.2677                   22.2552
# 2                      0.0000            0.2745                   36.1694
# 3                      0.0092            0.0092                   34.7782
# 4                      0.0000            0.0737                   16.8161
#
#    Vegetable Oils_protein  Vegetables_protein  Miscellaneous_protein
# 0                  0.0000              1.1370                 0.0462
# 1                  0.0084              3.2456                 0.0544
# 2                  0.0269              3.1267                 0.1399
# 3                  0.0092              0.8133                 0.0924
# 4                  0.0430              1.6024                 0.2947
#
# [5 rows x 78 columns]

# %% [markdown]
# <h2>3. Pandas Quiz: Sorting and Filtering </h2>

# %% [markdown]
# Buatlah sebuah data atau gunakan data gabungan dari soal no.2, dimana data ini di sort dari yang terbesar ke yang terkecil berdasarkan column Obesitas.
#
# Kemudian Lakukan Perintah Berikut :
#
# - print data hasil sorting
# - Berapa persen jumlah obesitas di Indonesia berdasarkan populasinya? kemudian tunjukan cara mendapatkannya!
# - Urutan ke berapakah Indonesia mengenai proposi penduduk yang obesitas berdasarkan total populasinya dari yang terbesar? kemudian tunjukan cara mendapatkannya!

# %%
# print Hasil Sorting
df_merge_sorted = df_merge.sort_values(by= 'Obesity', ascending= False)

df_merge_sorted
# Out:
#                       Country  Alcoholic Beverages_food  Animal fats_food  \
# 80                   Kiribati                    0.2970            0.0486
# 131                     Samoa                    1.4236            0.2262
# 161  United States of America                    4.8647            0.1681
# 83                     Kuwait                    0.0044            0.0022
# 133              Saudi Arabia                    0.0000            0.3917
# ..                        ...                       ...               ...
# 150               Timor-Leste                    0.4459            0.0897
# 166                   Vietnam                    1.4591            0.1640
# 52           French Polynesia                    4.6997            0.0309
# 109             New Caledonia                    5.0363            0.0821
# 147                   Taiwan*                    2.7663            0.1577
#
#      Animal Products_food  Aquatic Products, Other_food  \
# 80                 8.8958                        0.0000
# 131               11.1630                        0.1236
# 161               21.2352                        0.0020
# 83                10.7213                        0.0022
# 133               12.9962                        0.0000
# ..                    ...                           ...
# 150                5.4983                        0.0000
# 166                8.5765                        0.0042
# 52                14.3585                        0.0169
# 109               11.7818                        0.0804
# 147               12.1312                        0.0281
#
#      Cereals - Excluding Beer_food  Eggs_food  Fish, Seafood_food  \
# 80                          8.2747     0.1640              6.1065
# 131                         3.6768     0.1314              2.7788
# 161                         5.5048     0.7860              1.1287
# 83                         11.4132     1.3306              0.8343
# 133                        16.3284     0.6003              1.0369
# ..                             ...        ...                 ...
# 150                        26.3320     0.1025              1.0225
# 166                        16.8740     0.3077              2.6392
# 52                          7.6479     0.5386              3.4809
# 109                         8.5840     0.7494              2.0361
# 147                        10.0808     1.0900              2.3182
#
#      Fruits - Excluding Wine_food  Meat_food  ...  Spices_protein  \
# 80                         5.8907     2.3856  ...          0.0203
# 131                       10.7845     5.7993  ...          0.1574
# 161                        4.5432     6.2645  ...          0.1231
# 83                         5.3058     4.8770  ...          0.4057
# 133                        7.0413     4.9529  ...          0.4112
# ..                            ...        ...  ...             ...
# 150                        2.1027     4.0376  ...          0.0866
# 166                        5.9029     4.4382  ...          0.5221
# 52                         4.3512     7.0798  ...          0.0255
# 109                        5.5855     5.8687  ...          0.0967
# 147                        8.3904     6.0558  ...          0.2041
#
#      Starchy Roots_protein  Stimulants_protein  Sugar Crops_protein  \
# 80                  2.6583              0.0676               0.0000
# 131                 3.5860              0.5248               0.0000
# 161                 1.0640              0.6331               0.0000
# 83                  0.9416              0.6211               0.0000
# 133                 0.3141              0.4512               0.0000
# ..                     ...                 ...                  ...
# 150                 1.0135              1.2474               0.0000
# 166                 0.2333              0.5444               0.0167
# 52                  0.9036              0.3471               0.0255
# 109                 0.7431              0.4591               0.0000
# 147                 0.2391              0.3557               0.0117
#
#      Sugar & Sweeteners_protein  Treenuts_protein  Vegetal Products_protein  \
# 80                       0.0000            0.3179                   25.0338
# 131                      0.0058            0.0292                   19.0904
# 161                      0.0747            0.4924                   17.5247
# 83                       0.0000            0.4107                   26.2459
# 133                      0.0000            0.2799                   28.8594
# ..                          ...               ...                       ...
# 150                      0.0000            0.0000                   36.4432
# 166                      0.0056            0.3277                   29.5617
# 52                       0.0000            0.1174                   17.0044
# 109                      0.0000            0.1087                   20.8240
# 147                      0.0000            0.5364                   25.2362
#
#      Vegetable Oils_protein  Vegetables_protein  Miscellaneous_protein
# 80                   0.0000              1.3731                 0.1420
# 131                  0.0058              0.5364                 0.3032
# 161                  0.0835              1.3981                 0.0000
# 83                   0.0050              2.7047                 0.3907
# 133                  0.0057              1.0966                 0.3941
# ..                      ...                 ...                    ...
# 150                  0.0087              0.9356                 0.1992
# 166                  0.0000              3.7216                 0.0389
# 52                   0.0153              1.2558                 1.1129
# 109                  0.0362              1.7640                 1.1841
# 147                  0.0058              2.8571                 0.0991
#
# [170 rows x 78 columns]

# %%
# code untuk mendapatkan nilai proporsi obesitas di Indonesia
indo_filter = df_merge['Country'] == 'Indonesia' 
indo_data = df_merge[indo_filter]
print('Persentase Obesitas di Indonesia adalah', float(indo_data['Obesity'].values), '%'+' dari total jumlah populasi sebesar', float(indo_data['Population'].values))
# Out:
# Persentase Obesitas di Indonesia adalah 6.9 % dari total jumlah populasi sebesar 268419000.0

# %%
# code untuk mendapatkan urutan indoensia mengenai proposi obesitas dari terbesar
df_merge_sorted_new_index = df_merge_sorted.reset_index(drop= True)
df_merge_sorted_new_index.index += 1
indo_filter_2 = df_merge_sorted_new_index['Country'] == 'Indonesia' 
df_merge_sorted_new_index[indo_filter_2]

print('Indonesia berada pada urutan', int(df_merge_sorted_new_index[indo_filter_2].index.values), 'dari 170 negara berdasarkan persentase obesitas terbesar terhadap jumlah penduduk')
# Out:
# Indonesia berada pada urutan 139 dari 170 negara berdasarkan persentase obesitas terbesar terhadap jumlah penduduk

# %% [markdown]
# <h2>4. Pandas Quiz: Binning Data, Grouping, dan Aggregating </h2>

# %% [markdown]
# Binning data Terkonfirmasi COVID-19 (column Confirmed) dari data food supply menjadi 5 bagian berdasarkan quartile. kalian dapat menggunakan fungsi qcut untuk melakukan bininng ini. Masukan data hasil binning tersebut menjadi column baru untuk data food supply. misalkan beri nama column tersebut dengan 'Confirmed Category'. Berikan label 'Sangat Tidak Banyak', 'Tidak Banyak', 'Sedang', 'Cukup Banyak', 'Sangat Banyak'. untuk masing-masing binning dari interval yang memiliki nilai terkecil sampai yang terbesar
#
# Baca dokumentasi berikut untuk fungsi qcut : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.qcut.html
#
# - Buat data baru yang berupa data grouping semua data berdasarkan column Hasil Bininng atau column 'Confirmed Category'.
# - Grouping hanya column 'Obesity', 'Meat', 'Fruits - Excluding Wine', 'Fish, Seafood', 'Animal Products', 'Vegetal Products' saja.
# - Kemudian Aggregate dengan fungsi mean.
#
# Expected Output :
#
# ![alt text](https://drive.google.com/uc?id=1LZIgWZqDTl2WGBjS_M1nAqNGFTTmqC0Q)

# %%
# Code Here
bin_labels = ['Sangat Tidak Banyak', 'Tidak Banyak', 'Sedang', 'Cukup Banyak', 'Sangat Banyak']
df_food['Confirmed Category']= pd.qcut(df_food['Confirmed'], 5, labels= bin_labels)
gavno = df_food[['Obesity', 'Meat', 'Fruits - Excluding Wine', 'Fish, Seafood', 'Animal Products', 'Vegetal Products', 'Confirmed Category']].groupby(['Confirmed Category']).mean()

gavno
# Out:
#                        Obesity      Meat  Fruits - Excluding Wine  \
# Confirmed Category
# Sangat Tidak Banyak   9.638710  2.469409                 4.668353
# Tidak Banyak         13.359375  2.346237                 5.606913
# Sedang               20.818750  3.748703                 7.007013
# Cukup Banyak         23.503125  4.100750                 5.838347
# Sangat Banyak        25.021875  4.080863                 5.123728
#
#                      Fish, Seafood  Animal Products  Vegetal Products
# Confirmed Category
# Sangat Tidak Banyak       1.126916         8.125766         41.871125
# Tidak Banyak              1.376078         8.392828         41.604038
# Sedang                    1.263928        12.157297         37.838928
# Cukup Banyak              1.504309        15.865656         34.131622
# Sangat Banyak             1.332544        17.182816         32.812416

# %%
gavno.to_csv('gavno.csv')

# %% [markdown]
# <h2>5. Matplotlib Visualization: Bar plot </h2>
#
# Gunakan data grouping pada soal sebelumnya untuk melakukan visualisasi. jika kalian tidak dapat menyelesaikan soal tersebut, maka silahkan download data berikut yang merupakan hasil dari data grouping.
#
# [Download](https://drive.google.com/uc?export=download&id=1ZHnO7O4yRUMiPmsX5zB_S_oB-w8lD1Yf)
#
# Normalisasi data hasil grouping tersebut dengan rumus min-max normalisasi seperti di gambar. Kemudian buatlah grouping Visualization dengan berplot, visualisasikan data column 'Obesity', 'Fruits - Excluding Wine', 'Fish, Seafood', 'Animal Products' dan 'Vegetal Products'.
#
# Expected Output yang di hasilkan seperti gambar berikut.
#
# ![alt text](https://drive.google.com/uc?id=1v7aJMCeD_sUaZ0WQaQzAxCTy_EUJ7E4M)

# %% [markdown]
# ## Rumus Normalisasi
#
# ![alt text](https://drive.google.com/uc?id=1_1ueCPAPC1ialSsfQQ9Wm_TmGP9u-kEo)

# %% [markdown]
# ## Expected Ouput Data Hasil Normalisasi
#
# ![alt text](https://drive.google.com/uc?id=1Y7X46acxUUSSByjsL99LMurNF8018Zbv)

# %%
# Code Here
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 

df_confirmed = pd.read_csv('gavno.csv', index_col= 'Confirmed Category')

def normalisasi(x) : 
    normal_value = (x - x.min()) / (x.max() - x.min())
    return normal_value

df_confirmed_normal = df_confirmed.transform(normalisasi)
df_confirmed_normal_trans = df_confirmed_normal.transpose()
x = np.arange(len(df_confirmed_normal_trans.index))
labels = df_confirmed_normal_trans.columns

z = 0
width = 0.1
plt.style.use('fast')
fig, ax = plt.subplots(figsize= [16,8])
ax_list = []
while z < len(labels) :
    ax_list.append(ax.bar(x + z * width, df_confirmed_normal_trans[labels[z]], width, label=labels[z]))
    z += 1


  
ax.set_xticks(x)
ax.set_xticklabels(df_confirmed_normal_trans.index)
ax.set_title('Perbandingan Konsumsi Makanan Berdasarkan Tingkat Kasus COVID-19')
fig.legend()

def autolabel(bar_list):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for i in bar_list :
        for rect in i:
            height = rect.get_height()
            ax.annotate('{:.2f}'.format(height), xy=(rect.get_x() + rect.get_width() / 2, height),
            xytext=(0, 3),  # 3 points vertical offset 
            textcoords="offset points", ha='center', va='bottom')

autolabel(ax_list)

plt.show()

# %% [markdown]
# <h2>6. Matplotlib Visualization: Scatter Plot </h2>

# %% [markdown]
# Buatlah visualisasi perbandingan scatter plot dimana kita akan membandingkan respon Jumlah Kasus Covid-19 yang terkonfirmasi berdasarkan Supply Sayuran. dimana :
# - Tandai proporsi kematian jumlah kematian (column Death) dengan ukuran dari data poin.
# - Tandai proporsi produk hewani (column Animal Product) dengan warna, berikan colormap 'gist_yarg'.
#
# Expected Output :
#
# ![alt text](https://drive.google.com/uc?id=1eAzqLAdj7Ef-pvJ4dyr0nUB-EuUldGIo)
